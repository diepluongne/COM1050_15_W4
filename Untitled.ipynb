# %% [markdown]
# # A1

# %%
n=int(input())
tong=0
for i in range (1,n+1):
    tong+=i
print(tong)
# Out:
#  5
# 15

# %% [markdown]
# # A2

# %%
n=int(input())
def nguyenduong(a):
    while a<0:
        a=int(input())
    else:
        return a
n=nguyenduong(n)
def nguyento(a):
    for i in range (2,n):
        if n%i==0 :
            i=i+1
            return("NO")
    return ("YES")
nguyento(n)
# Out:
#  5
# 'YES'

# %% [markdown]
# # A5

# %%
n=int(input())
for i in range (1,n+1):
    x=int(input())
a=[]
a.append(x)
if 42 in a :
    print ("i've found the meaning of life")
else:
    print ("it's a joke")
# Out:
#  2
#  4
#  42
# i've found the meaning of life

# %% [markdown]
# # A7

# %%
n=int(input())
a=[]
def nguyento(n):
    if n<=1:
        return False
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            return False
    return True
ketqua=0
for i in range (1,n+1):
    if n%i==0 and nguyento(i):
       a.append (i)
       ketqua=max(a)
print(ketqua)
# Out:
#  9
# 3

# %% [markdown]
# # A3

# %%
n=int(input())
giaithua=1
for i in range (1,n+1):
    giaithua=giaithua*i
    i=i+1
print(giaithua)
# Out:
#  9
# 362880

# %% [markdown]
# # A12

# %%
n=int(input("số tháng người đó gửi"))
p=int(input("số tiền ban đầu"))
a=p*(1+0.7/100)**n
print(a)
# Out:
# số tháng người đó gửi 2
# số tiền ban đầu 100
# 101.40489999999997

# %% [markdown]
# # A11

# %%
n=int(input())
dem=0
for i in range(1,n+1):
    if n%i==0 and i%2==0:
        dem=dem+1
print(dem)
# Out:
#  6
# 2
